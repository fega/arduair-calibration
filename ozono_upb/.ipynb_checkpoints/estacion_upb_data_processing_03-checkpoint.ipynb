# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import xlrd
# %matplotlib inline

# %%
df=pd.read_csv('03_upb3.csv')
df= df[['date time','photo_raw_ozone']]
df
# Out:
#             date time  millis  samp_temp  samp_press  samp_flow  pump_status  \
# 0   04/21/17 00:00:00    32.2      671.0         777          1          3.1
# 1   04/21/17 00:30:00    32.3      670.9         778          1          1.3
# 2   04/21/17 01:00:00    32.3      670.5         776          1          3.5
# 3   04/21/17 01:30:00    32.5      670.4         777          1          3.2
# 4   04/21/17 02:00:00    32.2      670.4         776          1          1.7
# 5   04/21/17 02:30:00    32.2      670.3         776          1          0.5
# 6   04/21/17 03:00:00    32.2      670.3         776          1          0.8
# 7   04/21/17 03:30:00    32.1      670.4         775          1          1.6
# 8   04/21/17 04:00:00    32.1      670.5         776          1          2.8
# 9   04/21/17 04:30:00    32.1      670.6         774          1          3.2
# 10  04/21/17 05:00:00    32.1      670.8         775          1          1.3
# ...

# %%
df['photo_raw_ozone'].plot()
