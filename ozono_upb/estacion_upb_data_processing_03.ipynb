# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
import xlrd
# %matplotlib inline

# %%
data=pd.read_csv('03_upb_raw.csv')

# %%
df=pd.read_csv('03_upb.csv')
#df= df[['date time','photo_raw_ozone']]
df
# Out:
#      Unnamed: 0  Unnamed: 0.1            date time  millis  samp_temp  \
# 0         45053         45053  2017-04-17 00:00:00    31.6      669.7
# 1         45054         45054  2017-04-17 00:30:00    31.7      669.8
# 2         45055         45055  2017-04-17 01:00:00    32.0      670.0
# 3         45056         45056  2017-04-17 01:30:00    32.3      669.9
# 4         45057         45057  2017-04-17 02:00:00    32.3      669.8
# 5         45058         45058  2017-04-17 02:30:00    32.0      669.8
# 6         45059         45059  2017-04-17 03:00:00    31.4      670.2
# 7         45060         45060  2017-04-17 03:30:00    31.9      670.7
# 8         45061         45061  2017-04-17 04:00:00    32.0      670.5
# 9         45062         45062  2017-04-17 04:30:00    31.4      670.6
# 10        45063         45063  2017-04-17 05:00:00    31.1      670.8
# 11        45064         45064  2017-04-17 05:30:00    31.7      670.8
# ...

# %%
data.to_csv('03_upb_raw.csv')
data['photo_raw_ozone'].plot()

# %%
df.plot()
